# %%
import pandas as pd

# %%
df_original = pd.read_csv("siRNA_0715/train_data.csv")
n_original = df_original.shape[0]
df_submit = pd.read_csv("siRNA_0715/sample_submission.csv")
df = pd.concat([df_original, df_submit], axis=0).reset_index(drop=True)

# %%
def siRNA_feat_builder(s: pd.Series, anti: bool = False):
    name = "anti" if anti else "sense"
    df = s.to_frame()
    df[f"feat_siRNA_{name}_seq_len"] = s.str.len()
    for pos in [0, -1]:
        for c in list("AUGC"):
            df[f"feat_siRNA_{name}_seq_{c}_{'front' if pos == 0 else 'back'}"] = (
                s.str[pos] == c
            )
    df[f"feat_siRNA_{name}_seq_pattern_1"] = s.str.startswith("AA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_2"] = s.str.startswith("GA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_3"] = s.str.startswith("CA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_4"] = s.str.startswith("UA") & s.str.endswith(
        "UU"
    )
    df[f"feat_siRNA_{name}_seq_pattern_5"] = s.str.startswith("UU") & s.str.endswith(
        "AA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_6"] = s.str.startswith("UU") & s.str.endswith(
        "GA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_7"] = s.str.startswith("UU") & s.str.endswith(
        "CA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_8"] = s.str.startswith("UU") & s.str.endswith(
        "UA"
    )
    df[f"feat_siRNA_{name}_seq_pattern_9"] = s.str[1] == "A"
    df[f"feat_siRNA_{name}_seq_pattern_10"] = s.str[-2] == "A"
    df[f"feat_siRNA_{name}_seq_pattern_GC_frac"] = (
        s.str.contains("G") + s.str.contains("C")
    ) / s.str.len()
    return df.iloc[:, 1:]

# %%
def siRNA_feat_builder3(s: pd.Series, anti: bool = False):
    name = "anti" if anti else "sense"
    df = s.to_frame()

    # 长度分组
    df[f"feat_siRNA_{name}_len21"] = (s.str.len() == 21)
    # 省略号标识以此类推构造特征
    ...

    # GC含量
    GC_frac = (s.str.count("G") + s.str.count("C"))/s.str.len()
    df[f"feat_siRNA_{name}_GC_in"] = (GC_frac >= 0.36) & (GC_frac <= 0.52)

    # 局部GC含量
    GC_frac1 = (s.str[1:7].str.count("G") + s.str[1:7].str.count("C"))/s.str[1:7].str.len()
    ...
    
    df[f"feat_siRNA_{name}_GC_in1"] = GC_frac1
    ...

    return df.iloc[:, 1:]

# %%
def siRNA_feat_builder3_mod(s: pd.Series, anti: bool = False):
    name = "anti" if anti else "sense"
    df = s.to_frame()
    
    # 修饰RNA的起始、终止位置单元类别
    for pos in [0, -1]:
        for c in voc_ls:
            ...
    for pos in [1, -2]:
        for c in voc_ls:
            ...

    return df.iloc[:, 1:]

# %%
class GenomicTokenizer:
    def __init__(self, ngram=5, stride=2):
        # 初始化分词器，设置n-gram长度和步幅
        self.ngram = ngram
        self.stride = stride
        
    def tokenize(self, t):

        # 字符串变list
        if isinstance(t, str):
            t = list(t)

        if self.ngram == 1:
            # 如果n-gram长度为1，直接将序列转换为字符列表
            toks = t
        else:
            # 否则，按照步幅对序列进行n-gram分词
            toks = [t[i:i+self.ngram] for i in range(0, len(t), self.stride) if len(t[i:i+self.ngram]) == self.ngram]
        
            # 如果最后一个分词长度小于n-gram，移除最后一个分词
            if len(toks[-1]) < self.ngram:
                toks = toks[:-1]

            # sub list to str
            toks = [''.join(x) for x in toks]

        # 返回分词结果
        return toks

class GenomicVocab:
    def __init__(self, itos):
        # 初始化词汇表，itos是一个词汇表列表
        self.itos = itos
        # 创建从词汇到索引的映射
        self.stoi = {v: k for k, v in enumerate(self.itos)}
        
    @classmethod
    def create(cls, tokens, max_vocab, min_freq):
        # 创建词汇表类方法
        # 统计每个token出现的频率
        freq = Counter(tokens)
        # 选择出现频率大于等于min_freq的token，并且最多保留max_vocab个token
        # itos = ['<pad>'] + [o for o, c in freq.most_common(max_vocab - 1) if c >= min_freq]
        itos = [o for o, c in freq.most_common(max_vocab - 1) if c >= min_freq]
        # 返回包含词汇表的类实例
        return cls(itos)
    
def siRNA_feat_builder_substr(se, name, patterns):
    
    # 创建一个空字典来存储特征
    features = {}

    for pattern in patterns:
        try:
            # escaped_pattern = re.escape(pattern)  # 转义模式中的特殊字符
            escaped_pattern = pattern
            features[f"feat_{name}_seq_pattern_{escaped_pattern}"] = se.str.count(escaped_pattern)
        except re.error as e:
            print(f"Error in pattern {pattern}: {e}")

    # 将字典转换为DataFrame
    feature_df = pd.DataFrame(features)

    return feature_df

# %%
df_publication_id = pd.get_dummies(df.publication_id)
df_publication_id.columns = [
    f"feat_publication_id_{c}" for c in df_publication_id.columns
]
df_gene_target_symbol_name = pd.get_dummies(df.gene_target_symbol_name)
df_gene_target_symbol_name.columns = [
    f"feat_gene_target_symbol_name_{c}" for c in df_gene_target_symbol_name.columns
]
df_gene_target_ncbi_id = pd.get_dummies(df.gene_target_ncbi_id)
df_gene_target_ncbi_id.columns = [
    f"feat_gene_target_ncbi_id_{c}" for c in df_gene_target_ncbi_id.columns
]
df_gene_target_species = pd.get_dummies(df.gene_target_species)
df_gene_target_species.columns = [
    f"feat_gene_target_species_{c}" for c in df_gene_target_species.columns
]
siRNA_duplex_id_values = df.siRNA_duplex_id.str.split("-|\.").str[1].astype("int")
siRNA_duplex_id_values = (siRNA_duplex_id_values - siRNA_duplex_id_values.min()) / (
    siRNA_duplex_id_values.max() - siRNA_duplex_id_values.min()
)
df_siRNA_duplex_id = pd.DataFrame(siRNA_duplex_id_values)
df_cell_line_donor = pd.get_dummies(df.cell_line_donor)
df_cell_line_donor.columns = [
    f"feat_cell_line_donor_{c}" for c in df_cell_line_donor.columns
]
df_cell_line_donor["feat_cell_line_donor_hepatocytes"] = (
    (df.cell_line_donor.str.contains("Hepatocytes")).fillna(False).astype("int")
)
df_cell_line_donor["feat_cell_line_donor_cells"] = (
    df.cell_line_donor.str.contains("Cells").fillna(False).astype("int")
)
df_siRNA_concentration = df.siRNA_concentration.to_frame()
df_Transfection_method = pd.get_dummies(df.Transfection_method)
df_Transfection_method.columns = [
    f"feat_Transfection_method_{c}" for c in df_Transfection_method.columns
]
df_Duration_after_transfection_h = pd.get_dummies(df.Duration_after_transfection_h)
df_Duration_after_transfection_h.columns = [
    f"feat_Duration_after_transfection_h_{c}"
    for c in df_Duration_after_transfection_h.columns
]
feats = pd.concat(
    [
        df_publication_id,
        df_gene_target_symbol_name,
        df_gene_target_ncbi_id,
        df_gene_target_species,
        df_siRNA_duplex_id,
        df_cell_line_donor,
        df_siRNA_concentration,
        df_Transfection_method,
        df_Duration_after_transfection_h,
        siRNA_feat_builder(df.siRNA_sense_seq, False),
        siRNA_feat_builder(df.siRNA_antisense_seq, True),
        siRNA_feat_builder3(df.siRNA_sense_seq, False),
        siRNA_feat_builder3(df.siRNA_antisense_seq, True),
        # siRNA_feat_builder3_mod(df.siRNA_sense_seq, False),
        # siRNA_feat_builder3_mod(df.siRNA_antisense_seq, True),
        df.iloc[:, -1].to_frame(),
    ],
    axis=1,
)

# %%
print(feats.shape)
# Out:
# (30656, 209)

# %%
feats.head(10)
# Out:
#    feat_publication_id_WO0b0a8fec3d  feat_publication_id_WO0beeb1f407  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
# 5                             False                             False
# 6                             False                             False
# 7                             False                             False
# 8                             False                             False
# 9                             False                             False
#
#    feat_publication_id_WO181a7d3a16  feat_publication_id_WO182f2c5b3a  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
# 5                             False                             False
# 6                             False                             False
# 7                             False                             False
# 8                             False                             False
# 9                             False                             False
#
#    feat_publication_id_WO1b379c9eef  feat_publication_id_WO2185a478f7  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
# 5                             False                             False
# 6                             False                             False
# 7                             False                             False
# 8                             False                             False
# 9                             False                             False
#
#    feat_publication_id_WO2527cd3fe5  feat_publication_id_WO28aca1a182  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
# 5                             False                             False
# 6                             False                             False
# 7                             False                             False
# 8                             False                             False
# 9                             False                             False
#
#    feat_publication_id_WO28b5990c45  feat_publication_id_WO2b901a9fb5  ...  \
# 0                             False                             False  ...
# 1                             False                             False  ...
# 2                             False                             False  ...
# 3                             False                             False  ...
# 4                             False                             False  ...
# 5                             False                             False  ...
# 6                             False                             False  ...
# 7                             False                             False  ...
# 8                             False                             False  ...
# 9                             False                             False  ...
#
#    feat_siRNA_anti_seq_pattern_9  feat_siRNA_anti_seq_pattern_10  \
# 0                          False                            True
# 1                          False                           False
# 2                          False                           False
# 3                           True                           False
# 4                          False                            True
# 5                          False                           False
# 6                          False                           False
# 7                           True                            True
# 8                           True                           False
# 9                          False                           False
#
#    feat_siRNA_anti_seq_pattern_GC_frac  feat_siRNA_sense_len21  \
# 0                             0.043478                    True
# 1                             0.043478                    True
# 2                             0.043478                    True
# 3                             0.043478                    True
# 4                             0.043478                    True
# 5                             0.043478                    True
# 6                             0.043478                    True
# 7                             0.043478                    True
# 8                             0.043478                    True
# 9                             0.043478                    True
#
#    feat_siRNA_sense_GC_in  feat_siRNA_sense_GC_in1  feat_siRNA_anti_len21  \
# 0                    True                 0.500000                  False
# 1                   False                 0.000000                  False
# 2                   False                 0.166667                  False
# 3                    True                 0.666667                  False
# 4                   False                 0.500000                  False
# 5                   False                 0.500000                  False
# 6                    True                 0.666667                  False
# 7                   False                 0.500000                  False
# 8                    True                 0.500000                  False
# 9                    True                 0.333333                  False
#
#    feat_siRNA_anti_GC_in  feat_siRNA_anti_GC_in1  mRNA_remaining_pct
# 0                   True                0.500000               29.76
# 1                  False                0.333333               30.88
# 2                  False                0.500000               28.87
# 3                   True                0.166667               46.81
# 4                  False                0.166667               11.06
# 5                  False                0.333333               35.28
# 6                   True                0.333333               29.36
# 7                  False                0.166667               12.52
# 8                   True                0.500000               92.74
# 9                   True                0.166667               33.69
#
# [10 rows x 209 columns]

# %%
# adaptive_learning_rate函数用于自适应学习率
def adaptive_learning_rate(decay_rate=0.8, patience=50):
    best_score = float("-inf")  # 初始化为负无穷,因为分数越高越好
    wait = 0

    def callback(env):
        nonlocal best_score, wait
        current_score = env.evaluation_result_list[-1][2]  # 假设使用的是最后一个评估指标
        current_lr =  env.model.params.get('learning_rate')

        if current_score > best_score: 
            best_score = current_score
            # wait = 0 # 需要连续的score没有上升
        else:
            wait += 1

        if wait >= patience:
            new_lr = float(current_lr) * decay_rate
            wait = 0
            env.model.params['learning_rate'] = new_lr
            print(f"Learning rate adjusted to {env.model.params.get('learning_rate')}")

    return callback

# %%
# calculate_metrics函数用于计算评估指标
def calculate_metrics(preds, data, threshold=30):
    y_pred = preds
    y_true = data.get_label()
    mae = np.mean(np.abs(y_true - y_pred))
    # if mae < 0: mae = 0
    # elif mae >100: mae = 100

    y_true_binary = ((y_true <= threshold) & (y_true >= 0)).astype(int)
    y_pred_binary = ((y_pred <= threshold) & (y_pred >= 0)).astype(int)

    mask = (y_pred >= 0) & (y_pred <= threshold)
    range_mae = (
        mean_absolute_error(y_true[mask], y_pred[mask]) if np.sum(mask) > 0 else 100
    )
    # if range_mae < 0: range_mae = 0
    # elif range_mae >100: range_mae = 100

    # precision = precision_score(y_true_binary, y_pred_binary, average="binary")
    # recall = recall_score(y_true_binary, y_pred_binary, average="binary")

    if np.sum(y_pred_binary) > 0:
        precision = (np.array(y_pred_binary) & y_true_binary).sum()/np.sum(y_pred_binary)
    else:
        precision = 0
    if np.sum(y_true_binary) > 0:
        recall = (np.array(y_pred_binary) & y_true_binary).sum()/np.sum(y_true_binary)
    else:
        recall = 0

    if precision + recall == 0:
        f1 = 0
    else:
        f1 = 2 * precision * recall / (precision + recall)
    score = (1 - mae / 100) * 0.5 + (1 - range_mae / 100) * f1 * 0.5
    return "custom_score", score, True  # True表示分数越高越好

# %%
# train函数用于训练模型
def gbms_train(feats, n_original):
    # 定义k折交叉验证
    n_splits = 10
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    # 开始k折交叉验证
    gbms = []
    for fold, (train_idx, val_idx) in enumerate(
        kf.split(feats.iloc[:n_original, :]), 1
    ):
        # 准备训练集和验证集
        X_train, X_val = feats.iloc[train_idx, :-1], feats.iloc[val_idx, :-1]
        y_train, y_val = feats.iloc[train_idx, -1], feats.iloc[val_idx, -1]
        weight_ls = np.array(feats['mRNA_remaining_pct'].apply(lambda x:2 if ((x<=30)and(x>=0)) else 1))
        w_train = weight_ls[train_idx]
        

        # 创建LightGBM数据集
        train_data = lgb.Dataset(X_train, label=y_train, weight=w_train)
        val_data = lgb.Dataset(X_val, label=y_val, reference=train_data)

        boost_round = 25000
        early_stop_rounds = int(boost_round*0.1)

        # 显示metric
        lgb_log = lgb.log_evaluation(period=200, show_stdv=True)
        lgb_stop = lgb.early_stopping(stopping_rounds=early_stop_rounds, first_metric_only=True, verbose=True, min_delta=0.00001)

        # 设置LightGBM参数
        params = {
            "boosting_type": "gbdt",
            "objective": "regression",
            "metric": "None",
            # "metric": "root_mean_squared_error",
            "max_depth": 8,
            "num_leaves": 63,
            "min_data_in_leaf": 2,
            "learning_rate": 0.05,
            "feature_fraction": 0.9,
            "lambda_l1": 0.1,
            "lambda_l2": 0.2,
            "verbose": -1, # -1时不输出
            "early_stopping_round": early_stop_rounds,
            "num_threads": 8,
        }

        # 在训练时使用自适应学习率回调函数
        adaptive_lr = adaptive_learning_rate(decay_rate=0.9, patience=1000)
        gbm = lgb.train(
            params,
            train_data,
            num_boost_round=boost_round,
            valid_sets=[val_data],
            feval=calculate_metrics,  # 将自定义指标函数作为feval参数传入
            # callbacks=[print_validation_result, adaptive_lr, lgb_log, lgb_stop],
            callbacks=[adaptive_lr, lgb_log, lgb_stop],
        )
        # params = {
        #     "boosting_type": "gbdt",
        #     "objective": "regression",
        #     "metric": "root_mean_squared_error",
        #     "max_depth": 10,
        #     "learning_rate": 0.01,
        #     "verbose": 0,
        # }
        # gbm = lgb.train(
        #     params,
        #     train_data,
        #     num_boost_round=30000,
        #     valid_sets=[test_data],
        #     callbacks=[print_validation_result],
        # )
        valid_score = gbm.best_score["valid_0"]["custom_score"]
        print(f"best_valid_score: {valid_score}")
        print(f"gbm position: {len(gbms)}")
        gbms.append(gbm)

    return gbms

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_absolute_error
import numpy as np

gbms = gbms_train(feats, n_original)
# Out:
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.734016
# [400]	valid_0's custom_score: 0.751139
# [600]	valid_0's custom_score: 0.762572
# [800]	valid_0's custom_score: 0.768902
# [1000]	valid_0's custom_score: 0.774316
# [1200]	valid_0's custom_score: 0.779931
# [1400]	valid_0's custom_score: 0.785218
# [1600]	valid_0's custom_score: 0.791173
# Learning rate adjusted to 0.045000000000000005
# [1800]	valid_0's custom_score: 0.795128
# [2000]	valid_0's custom_score: 0.799156
# [2200]	valid_0's custom_score: 0.801232
# [2400]	valid_0's custom_score: 0.800238
# [2600]	valid_0's custom_score: 0.802649
# [2800]	valid_0's custom_score: 0.804521
# Learning rate adjusted to 0.04050000000000001
# [3000]	valid_0's custom_score: 0.806056
# [3200]	valid_0's custom_score: 0.807458
# [3400]	valid_0's custom_score: 0.808404
# [3600]	valid_0's custom_score: 0.808006
# [3800]	valid_0's custom_score: 0.807638
# [4000]	valid_0's custom_score: 0.807384
# Learning rate adjusted to 0.03645000000000001
# [4200]	valid_0's custom_score: 0.808004
# [4400]	valid_0's custom_score: 0.808404
# [4600]	valid_0's custom_score: 0.809909
# [4800]	valid_0's custom_score: 0.810507
# [5000]	valid_0's custom_score: 0.808269
# Learning rate adjusted to 0.03280500000000001
# [5200]	valid_0's custom_score: 0.810582
# [5400]	valid_0's custom_score: 0.810502
# [5600]	valid_0's custom_score: 0.810911
# [5800]	valid_0's custom_score: 0.811023
# [6000]	valid_0's custom_score: 0.81122
# Learning rate adjusted to 0.02952450000000001
# [6200]	valid_0's custom_score: 0.810233
# [6400]	valid_0's custom_score: 0.809405
# [6600]	valid_0's custom_score: 0.809315
# [6800]	valid_0's custom_score: 0.809283
# [7000]	valid_0's custom_score: 0.808798
# Learning rate adjusted to 0.02657205000000001
# [7200]	valid_0's custom_score: 0.808522
# [7400]	valid_0's custom_score: 0.808933
# [7600]	valid_0's custom_score: 0.808484
# [7800]	valid_0's custom_score: 0.807565
# [8000]	valid_0's custom_score: 0.807982
# Learning rate adjusted to 0.02391484500000001
# [8200]	valid_0's custom_score: 0.807287
# [8400]	valid_0's custom_score: 0.806207
# Early stopping, best iteration is:
# [5900]	valid_0's custom_score: 0.811574
# Evaluated only: custom_score
# best_valid_score: 0.8115738349833941
# gbm position: 0
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.761774
# [400]	valid_0's custom_score: 0.784298
# [600]	valid_0's custom_score: 0.795387
# [800]	valid_0's custom_score: 0.803763
# [1000]	valid_0's custom_score: 0.807454
# [1200]	valid_0's custom_score: 0.810985
# [1400]	valid_0's custom_score: 0.815522
# [1600]	valid_0's custom_score: 0.817349
# Learning rate adjusted to 0.045000000000000005
# [1800]	valid_0's custom_score: 0.818492
# [2000]	valid_0's custom_score: 0.818515
# [2200]	valid_0's custom_score: 0.820116
# [2400]	valid_0's custom_score: 0.820377
# [2600]	valid_0's custom_score: 0.821674
# Learning rate adjusted to 0.04050000000000001
# [2800]	valid_0's custom_score: 0.821883
# [3000]	valid_0's custom_score: 0.821699
# [3200]	valid_0's custom_score: 0.821881
# [3400]	valid_0's custom_score: 0.821648
# [3600]	valid_0's custom_score: 0.822122
# Learning rate adjusted to 0.03645000000000001
# [3800]	valid_0's custom_score: 0.822876
# [4000]	valid_0's custom_score: 0.822254
# [4200]	valid_0's custom_score: 0.823446
# [4400]	valid_0's custom_score: 0.823929
# [4600]	valid_0's custom_score: 0.822557
# [4800]	valid_0's custom_score: 0.823004
# Learning rate adjusted to 0.03280500000000001
# [5000]	valid_0's custom_score: 0.821817
# [5200]	valid_0's custom_score: 0.82166
# [5400]	valid_0's custom_score: 0.821558
# [5600]	valid_0's custom_score: 0.821552
# [5800]	valid_0's custom_score: 0.82278
# Learning rate adjusted to 0.02952450000000001
# [6000]	valid_0's custom_score: 0.821435
# [6200]	valid_0's custom_score: 0.822081
# [6400]	valid_0's custom_score: 0.823417
# [6600]	valid_0's custom_score: 0.823878
# [6800]	valid_0's custom_score: 0.823196
# Learning rate adjusted to 0.02657205000000001
# [7000]	valid_0's custom_score: 0.824402
# [7200]	valid_0's custom_score: 0.824727
# [7400]	valid_0's custom_score: 0.824527
# [7600]	valid_0's custom_score: 0.824333
# [7800]	valid_0's custom_score: 0.823387
# Learning rate adjusted to 0.02391484500000001
# [8000]	valid_0's custom_score: 0.822554
# [8200]	valid_0's custom_score: 0.822222
# [8400]	valid_0's custom_score: 0.822498
# [8600]	valid_0's custom_score: 0.82244
# [8800]	valid_0's custom_score: 0.822257
# Learning rate adjusted to 0.021523360500000012
# [9000]	valid_0's custom_score: 0.82258
# [9200]	valid_0's custom_score: 0.822763
# Early stopping, best iteration is:
# [6892]	valid_0's custom_score: 0.825229
# Evaluated only: custom_score
# best_valid_score: 0.8252288800987962
# gbm position: 1
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.753246
# [400]	valid_0's custom_score: 0.770233
# [600]	valid_0's custom_score: 0.776115
# [800]	valid_0's custom_score: 0.783724
# [1000]	valid_0's custom_score: 0.789685
# [1200]	valid_0's custom_score: 0.794068
# [1400]	valid_0's custom_score: 0.79451
# Learning rate adjusted to 0.045000000000000005
# [1600]	valid_0's custom_score: 0.797808
# [1800]	valid_0's custom_score: 0.800606
# [2000]	valid_0's custom_score: 0.802916
# [2200]	valid_0's custom_score: 0.803967
# [2400]	valid_0's custom_score: 0.8061
# [2600]	valid_0's custom_score: 0.806066
# Learning rate adjusted to 0.04050000000000001
# [2800]	valid_0's custom_score: 0.805898
# [3000]	valid_0's custom_score: 0.806807
# [3200]	valid_0's custom_score: 0.808452
# [3400]	valid_0's custom_score: 0.808766
# [3600]	valid_0's custom_score: 0.807849
# Learning rate adjusted to 0.03645000000000001
# [3800]	valid_0's custom_score: 0.807035
# [4000]	valid_0's custom_score: 0.807872
# [4200]	valid_0's custom_score: 0.806893
# [4400]	valid_0's custom_score: 0.807272
# [4600]	valid_0's custom_score: 0.80734
# Learning rate adjusted to 0.03280500000000001
# [4800]	valid_0's custom_score: 0.808413
# [5000]	valid_0's custom_score: 0.809146
# [5200]	valid_0's custom_score: 0.809635
# [5400]	valid_0's custom_score: 0.808163
# [5600]	valid_0's custom_score: 0.807821
# Learning rate adjusted to 0.02952450000000001
# [5800]	valid_0's custom_score: 0.808169
# [6000]	valid_0's custom_score: 0.808245
# [6200]	valid_0's custom_score: 0.808274
# [6400]	valid_0's custom_score: 0.809535
# [6600]	valid_0's custom_score: 0.810174
# [6800]	valid_0's custom_score: 0.80989
# Learning rate adjusted to 0.02657205000000001
# [7000]	valid_0's custom_score: 0.809858
# [7200]	valid_0's custom_score: 0.809785
# [7400]	valid_0's custom_score: 0.808928
# [7600]	valid_0's custom_score: 0.80944
# [7800]	valid_0's custom_score: 0.80951
# Learning rate adjusted to 0.02391484500000001
# [8000]	valid_0's custom_score: 0.810382
# [8200]	valid_0's custom_score: 0.810326
# [8400]	valid_0's custom_score: 0.81153
# [8600]	valid_0's custom_score: 0.810365
# [8800]	valid_0's custom_score: 0.81086
# Learning rate adjusted to 0.021523360500000012
# [9000]	valid_0's custom_score: 0.8112
# [9200]	valid_0's custom_score: 0.811183
# [9400]	valid_0's custom_score: 0.810476
# [9600]	valid_0's custom_score: 0.810741
# [9800]	valid_0's custom_score: 0.811391
# Learning rate adjusted to 0.01937102445000001
# [10000]	valid_0's custom_score: 0.811114
# [10200]	valid_0's custom_score: 0.811332
# [10400]	valid_0's custom_score: 0.810417
# [10600]	valid_0's custom_score: 0.810806
# [10800]	valid_0's custom_score: 0.810282
# Learning rate adjusted to 0.01743392200500001
# [11000]	valid_0's custom_score: 0.80999
# [11200]	valid_0's custom_score: 0.810161
# [11400]	valid_0's custom_score: 0.810163
# [11600]	valid_0's custom_score: 0.810133
# [11800]	valid_0's custom_score: 0.810715
# Learning rate adjusted to 0.015690529804500006
# [12000]	valid_0's custom_score: 0.810694
# [12200]	valid_0's custom_score: 0.810698
# [12400]	valid_0's custom_score: 0.810617
# [12600]	valid_0's custom_score: 0.810919
# [12800]	valid_0's custom_score: 0.811233
# Learning rate adjusted to 0.014121476824050006
# [13000]	valid_0's custom_score: 0.81118
# [13200]	valid_0's custom_score: 0.81148
# [13400]	valid_0's custom_score: 0.810375
# [13600]	valid_0's custom_score: 0.810575
# [13800]	valid_0's custom_score: 0.810286
# Learning rate adjusted to 0.012709329141645007
# [14000]	valid_0's custom_score: 0.809534
# [14200]	valid_0's custom_score: 0.809811
# [14400]	valid_0's custom_score: 0.809547
# [14600]	valid_0's custom_score: 0.809527
# [14800]	valid_0's custom_score: 0.80987
# Learning rate adjusted to 0.011438396227480507
# [15000]	valid_0's custom_score: 0.809632
# [15200]	valid_0's custom_score: 0.809229
# [15400]	valid_0's custom_score: 0.809587
# [15600]	valid_0's custom_score: 0.809137
# best_valid_score: 0.8118902438470113
# gbm position: 2
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.750854
# [400]	valid_0's custom_score: 0.768813
# [600]	valid_0's custom_score: 0.781046
# [800]	valid_0's custom_score: 0.78683
# [1000]	valid_0's custom_score: 0.795059
# [1200]	valid_0's custom_score: 0.795968
# [1400]	valid_0's custom_score: 0.800188
# Learning rate adjusted to 0.045000000000000005
# [1600]	valid_0's custom_score: 0.803838
# [1800]	valid_0's custom_score: 0.80458
# [2000]	valid_0's custom_score: 0.807917
# [2200]	valid_0's custom_score: 0.809153
# [2400]	valid_0's custom_score: 0.807995
# [2600]	valid_0's custom_score: 0.80965
# Learning rate adjusted to 0.04050000000000001
# [2800]	valid_0's custom_score: 0.808282
# [3000]	valid_0's custom_score: 0.809158
# [3200]	valid_0's custom_score: 0.808607
# [3400]	valid_0's custom_score: 0.809073
# [3600]	valid_0's custom_score: 0.808873
# Learning rate adjusted to 0.03645000000000001
# [3800]	valid_0's custom_score: 0.808475
# [4000]	valid_0's custom_score: 0.809092
# [4200]	valid_0's custom_score: 0.808945
# [4400]	valid_0's custom_score: 0.809242
# [4600]	valid_0's custom_score: 0.80918
# Learning rate adjusted to 0.03280500000000001
# [4800]	valid_0's custom_score: 0.807924
# best_valid_score: 0.8104627455194371
# gbm position: 3
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.7469
# [400]	valid_0's custom_score: 0.763362
# [600]	valid_0's custom_score: 0.770081
# [800]	valid_0's custom_score: 0.778545
# [1000]	valid_0's custom_score: 0.783891
# [1200]	valid_0's custom_score: 0.786287
# [1400]	valid_0's custom_score: 0.789552
# Learning rate adjusted to 0.045000000000000005
# [1600]	valid_0's custom_score: 0.79438
# [1800]	valid_0's custom_score: 0.793046
# [2000]	valid_0's custom_score: 0.79523
# [2200]	valid_0's custom_score: 0.795436
# [2400]	valid_0's custom_score: 0.796983
# Learning rate adjusted to 0.04050000000000001
# [2600]	valid_0's custom_score: 0.79707
# [2800]	valid_0's custom_score: 0.796762
# [3000]	valid_0's custom_score: 0.797699
# [3200]	valid_0's custom_score: 0.796921
# [3400]	valid_0's custom_score: 0.800278
# [3600]	valid_0's custom_score: 0.800031
# Learning rate adjusted to 0.03645000000000001
# [3800]	valid_0's custom_score: 0.800213
# [4000]	valid_0's custom_score: 0.801316
# [4200]	valid_0's custom_score: 0.801007
# [4400]	valid_0's custom_score: 0.801229
# [4600]	valid_0's custom_score: 0.800198
# Learning rate adjusted to 0.03280500000000001
# [4800]	valid_0's custom_score: 0.800565
# [5000]	valid_0's custom_score: 0.799523
# [5200]	valid_0's custom_score: 0.799144
# [5400]	valid_0's custom_score: 0.797665
# [5600]	valid_0's custom_score: 0.798694
# Learning rate adjusted to 0.02952450000000001
# [5800]	valid_0's custom_score: 0.799148
# [6000]	valid_0's custom_score: 0.798671
# [6200]	valid_0's custom_score: 0.799563
# [6400]	valid_0's custom_score: 0.799018
# [6600]	valid_0's custom_score: 0.798485
# Learning rate adjusted to 0.02657205000000001
# [6800]	valid_0's custom_score: 0.799071
# best_valid_score: 0.8020030838774925
# gbm position: 4
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.751578
# [400]	valid_0's custom_score: 0.768193
# [600]	valid_0's custom_score: 0.77449
# [800]	valid_0's custom_score: 0.781029
# [1000]	valid_0's custom_score: 0.782299
# [1200]	valid_0's custom_score: 0.78804
# [1400]	valid_0's custom_score: 0.789706
# Learning rate adjusted to 0.045000000000000005
# [1600]	valid_0's custom_score: 0.795509
# [1800]	valid_0's custom_score: 0.797401
# [2000]	valid_0's custom_score: 0.796106
# [2200]	valid_0's custom_score: 0.800386
# [2400]	valid_0's custom_score: 0.803245
# [2600]	valid_0's custom_score: 0.803119
# Learning rate adjusted to 0.04050000000000001
# [2800]	valid_0's custom_score: 0.803531
# [3000]	valid_0's custom_score: 0.804617
# [3200]	valid_0's custom_score: 0.806206
# [3400]	valid_0's custom_score: 0.806477
# [3600]	valid_0's custom_score: 0.808339
# [3800]	valid_0's custom_score: 0.808568
# Learning rate adjusted to 0.03645000000000001
# [4000]	valid_0's custom_score: 0.808196
# [4200]	valid_0's custom_score: 0.808268
# [4400]	valid_0's custom_score: 0.80836
# [4600]	valid_0's custom_score: 0.807721
# [4800]	valid_0's custom_score: 0.809328
# Learning rate adjusted to 0.03280500000000001
# [5000]	valid_0's custom_score: 0.811648
# [5200]	valid_0's custom_score: 0.811557
# [5400]	valid_0's custom_score: 0.811769
# [5600]	valid_0's custom_score: 0.812384
# [5800]	valid_0's custom_score: 0.812554
# Learning rate adjusted to 0.02952450000000001
# [6000]	valid_0's custom_score: 0.814305
# [6200]	valid_0's custom_score: 0.814065
# [6400]	valid_0's custom_score: 0.814074
# [6600]	valid_0's custom_score: 0.814164
# [6800]	valid_0's custom_score: 0.814959
# [7000]	valid_0's custom_score: 0.815814
# Learning rate adjusted to 0.02657205000000001
# [7200]	valid_0's custom_score: 0.814708
# [7400]	valid_0's custom_score: 0.815274
# [7600]	valid_0's custom_score: 0.814809
# [7800]	valid_0's custom_score: 0.815485
# [8000]	valid_0's custom_score: 0.814956
# Learning rate adjusted to 0.02391484500000001
# [8200]	valid_0's custom_score: 0.815033
# [8400]	valid_0's custom_score: 0.814557
# [8600]	valid_0's custom_score: 0.814147
# [8800]	valid_0's custom_score: 0.814861
# [9000]	valid_0's custom_score: 0.815522
# Learning rate adjusted to 0.021523360500000012
# [9200]	valid_0's custom_score: 0.814447
# [9400]	valid_0's custom_score: 0.814324
# Early stopping, best iteration is:
# [6948]	valid_0's custom_score: 0.816547
# Evaluated only: custom_score
# best_valid_score: 0.8165473416663089
# gbm position: 5
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.74892
# [400]	valid_0's custom_score: 0.768684
# [600]	valid_0's custom_score: 0.774407
# [800]	valid_0's custom_score: 0.776434
# [1000]	valid_0's custom_score: 0.77825
# [1200]	valid_0's custom_score: 0.782385
# [1400]	valid_0's custom_score: 0.785822
# Learning rate adjusted to 0.045000000000000005
# [1600]	valid_0's custom_score: 0.786646
# [1800]	valid_0's custom_score: 0.789304
# [2000]	valid_0's custom_score: 0.792889
# [2200]	valid_0's custom_score: 0.796331
# [2400]	valid_0's custom_score: 0.80065
# [2600]	valid_0's custom_score: 0.801221
# Learning rate adjusted to 0.04050000000000001
# [2800]	valid_0's custom_score: 0.802577
# [3000]	valid_0's custom_score: 0.80124
# [3200]	valid_0's custom_score: 0.802231
# [3400]	valid_0's custom_score: 0.80221
# [3600]	valid_0's custom_score: 0.801595
# Learning rate adjusted to 0.03645000000000001
# [3800]	valid_0's custom_score: 0.802532
# [4000]	valid_0's custom_score: 0.803707
# [4200]	valid_0's custom_score: 0.803106
# [4400]	valid_0's custom_score: 0.805014
# [4600]	valid_0's custom_score: 0.806039
# Learning rate adjusted to 0.03280500000000001
# [4800]	valid_0's custom_score: 0.804595
# [5000]	valid_0's custom_score: 0.802766
# [5200]	valid_0's custom_score: 0.804153
# [5400]	valid_0's custom_score: 0.804548
# [5600]	valid_0's custom_score: 0.804574
# Learning rate adjusted to 0.02952450000000001
# [5800]	valid_0's custom_score: 0.804607
# [6000]	valid_0's custom_score: 0.805766
# [6200]	valid_0's custom_score: 0.804966
# [6400]	valid_0's custom_score: 0.804714
# [6600]	valid_0's custom_score: 0.80576
# Learning rate adjusted to 0.02657205000000001
# [6800]	valid_0's custom_score: 0.806863
# [7000]	valid_0's custom_score: 0.806382
# [7200]	valid_0's custom_score: 0.804467
# [7400]	valid_0's custom_score: 0.804867
# [7600]	valid_0's custom_score: 0.804235
# Learning rate adjusted to 0.02391484500000001
# [7800]	valid_0's custom_score: 0.804406
# [8000]	valid_0's custom_score: 0.805609
# [8200]	valid_0's custom_score: 0.805582
# [8400]	valid_0's custom_score: 0.805164
# [8600]	valid_0's custom_score: 0.805502
# Learning rate adjusted to 0.021523360500000012
# [8800]	valid_0's custom_score: 0.805526
# [9000]	valid_0's custom_score: 0.805235
# [9200]	valid_0's custom_score: 0.805169
# Early stopping, best iteration is:
# [6799]	valid_0's custom_score: 0.806862
# Evaluated only: custom_score
# best_valid_score: 0.8068622909206984
# gbm position: 6
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.756533
# [400]	valid_0's custom_score: 0.769374
# [600]	valid_0's custom_score: 0.782286
# [800]	valid_0's custom_score: 0.787431
# [1000]	valid_0's custom_score: 0.795919
# [1200]	valid_0's custom_score: 0.802021
# [1400]	valid_0's custom_score: 0.802766
# Learning rate adjusted to 0.045000000000000005
# [1600]	valid_0's custom_score: 0.80574
# [1800]	valid_0's custom_score: 0.805829
# [2000]	valid_0's custom_score: 0.809353
# [2200]	valid_0's custom_score: 0.811723
# [2400]	valid_0's custom_score: 0.81314
# [2600]	valid_0's custom_score: 0.813256
# Learning rate adjusted to 0.04050000000000001
# [2800]	valid_0's custom_score: 0.813284
# [3000]	valid_0's custom_score: 0.814018
# [3200]	valid_0's custom_score: 0.814579
# [3400]	valid_0's custom_score: 0.814875
# [3600]	valid_0's custom_score: 0.815909
# Learning rate adjusted to 0.03645000000000001
# [3800]	valid_0's custom_score: 0.814982
# [4000]	valid_0's custom_score: 0.815324
# [4200]	valid_0's custom_score: 0.814908
# [4400]	valid_0's custom_score: 0.816049
# [4600]	valid_0's custom_score: 0.817398
# Learning rate adjusted to 0.03280500000000001
# [4800]	valid_0's custom_score: 0.81668
# [5000]	valid_0's custom_score: 0.816017
# [5200]	valid_0's custom_score: 0.816126
# [5400]	valid_0's custom_score: 0.81498
# [5600]	valid_0's custom_score: 0.815303
# Learning rate adjusted to 0.02952450000000001
# [5800]	valid_0's custom_score: 0.814672
# [6000]	valid_0's custom_score: 0.815472
# [6200]	valid_0's custom_score: 0.814037
# [6400]	valid_0's custom_score: 0.814016
# [6600]	valid_0's custom_score: 0.813673
# Learning rate adjusted to 0.02657205000000001
# [6800]	valid_0's custom_score: 0.814374
# [7000]	valid_0's custom_score: 0.814573
# Early stopping, best iteration is:
# [4566]	valid_0's custom_score: 0.817414
# Evaluated only: custom_score
# best_valid_score: 0.8174135457293745
# gbm position: 7
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.745415
# [400]	valid_0's custom_score: 0.760665
# [600]	valid_0's custom_score: 0.768166
# [800]	valid_0's custom_score: 0.777026
# [1000]	valid_0's custom_score: 0.784818
# [1200]	valid_0's custom_score: 0.789078
# [1400]	valid_0's custom_score: 0.791874
# Learning rate adjusted to 0.045000000000000005
# [1600]	valid_0's custom_score: 0.792698
# [1800]	valid_0's custom_score: 0.794424
# [2000]	valid_0's custom_score: 0.797714
# [2200]	valid_0's custom_score: 0.798553
# [2400]	valid_0's custom_score: 0.79802
# [2600]	valid_0's custom_score: 0.799927
# Learning rate adjusted to 0.04050000000000001
# [2800]	valid_0's custom_score: 0.80025
# [3000]	valid_0's custom_score: 0.801257
# [3200]	valid_0's custom_score: 0.80523
# [3400]	valid_0's custom_score: 0.804618
# [3600]	valid_0's custom_score: 0.805944
# [3800]	valid_0's custom_score: 0.805962
# Learning rate adjusted to 0.03645000000000001
# [4000]	valid_0's custom_score: 0.806196
# [4200]	valid_0's custom_score: 0.80543
# [4400]	valid_0's custom_score: 0.806551
# [4600]	valid_0's custom_score: 0.804917
# [4800]	valid_0's custom_score: 0.805585
# Learning rate adjusted to 0.03280500000000001
# [5000]	valid_0's custom_score: 0.805451
# [5200]	valid_0's custom_score: 0.80671
# [5400]	valid_0's custom_score: 0.807225
# [5600]	valid_0's custom_score: 0.806645
# [5800]	valid_0's custom_score: 0.807616
# Learning rate adjusted to 0.02952450000000001
# [6000]	valid_0's custom_score: 0.807977
# [6200]	valid_0's custom_score: 0.807305
# [6400]	valid_0's custom_score: 0.808309
# [6600]	valid_0's custom_score: 0.807839
# [6800]	valid_0's custom_score: 0.807932
# Learning rate adjusted to 0.02657205000000001
# [7000]	valid_0's custom_score: 0.808307
# [7200]	valid_0's custom_score: 0.808275
# [7400]	valid_0's custom_score: 0.80865
# [7600]	valid_0's custom_score: 0.808779
# [7800]	valid_0's custom_score: 0.808077
# Learning rate adjusted to 0.02391484500000001
# [8000]	valid_0's custom_score: 0.80901
# [8200]	valid_0's custom_score: 0.808631
# [8400]	valid_0's custom_score: 0.809044
# [8600]	valid_0's custom_score: 0.808874
# [8800]	valid_0's custom_score: 0.807932
# Learning rate adjusted to 0.021523360500000012
# [9000]	valid_0's custom_score: 0.808551
# [9200]	valid_0's custom_score: 0.80912
# [9400]	valid_0's custom_score: 0.809373
# [9600]	valid_0's custom_score: 0.809041
# [9800]	valid_0's custom_score: 0.809604
# Learning rate adjusted to 0.01937102445000001
# [10000]	valid_0's custom_score: 0.809705
# [10200]	valid_0's custom_score: 0.810413
# [10400]	valid_0's custom_score: 0.811119
# [10600]	valid_0's custom_score: 0.81016
# [10800]	valid_0's custom_score: 0.811323
# [11000]	valid_0's custom_score: 0.811267
# Learning rate adjusted to 0.01743392200500001
# [11200]	valid_0's custom_score: 0.811292
# [11400]	valid_0's custom_score: 0.811108
# [11600]	valid_0's custom_score: 0.810674
# [11800]	valid_0's custom_score: 0.809747
# [12000]	valid_0's custom_score: 0.809835
# Learning rate adjusted to 0.015690529804500006
# [12200]	valid_0's custom_score: 0.810556
# [12400]	valid_0's custom_score: 0.810501
# [12600]	valid_0's custom_score: 0.810285
# [12800]	valid_0's custom_score: 0.810249
# Early stopping, best iteration is:
# [10307]	valid_0's custom_score: 0.811739
# Evaluated only: custom_score
# best_valid_score: 0.8117385943753714
# gbm position: 8
# Training until validation scores don't improve for 2500 rounds
# [200]	valid_0's custom_score: 0.727224
# [400]	valid_0's custom_score: 0.751136
# [600]	valid_0's custom_score: 0.762643
# [800]	valid_0's custom_score: 0.771643
# [1000]	valid_0's custom_score: 0.772903
# [1200]	valid_0's custom_score: 0.777564
# [1400]	valid_0's custom_score: 0.781987
# Learning rate adjusted to 0.045000000000000005
# [1600]	valid_0's custom_score: 0.782383
# [1800]	valid_0's custom_score: 0.786429
# [2000]	valid_0's custom_score: 0.787724
# [2200]	valid_0's custom_score: 0.789085
# [2400]	valid_0's custom_score: 0.790935
# [2600]	valid_0's custom_score: 0.792486
# Learning rate adjusted to 0.04050000000000001
# [2800]	valid_0's custom_score: 0.792893
# [3000]	valid_0's custom_score: 0.793978
# [3200]	valid_0's custom_score: 0.795868
# [3400]	valid_0's custom_score: 0.79547
# [3600]	valid_0's custom_score: 0.796171
# Learning rate adjusted to 0.03645000000000001
# [3800]	valid_0's custom_score: 0.795361
# [4000]	valid_0's custom_score: 0.797191
# [4200]	valid_0's custom_score: 0.797994
# [4400]	valid_0's custom_score: 0.798908
# [4600]	valid_0's custom_score: 0.799914
# [4800]	valid_0's custom_score: 0.801604
# Learning rate adjusted to 0.03280500000000001
# [5000]	valid_0's custom_score: 0.801078
# [5200]	valid_0's custom_score: 0.80208
# [5400]	valid_0's custom_score: 0.802324
# [5600]	valid_0's custom_score: 0.803528
# [5800]	valid_0's custom_score: 0.802838
# Learning rate adjusted to 0.02952450000000001
# [6000]	valid_0's custom_score: 0.803557
# [6200]	valid_0's custom_score: 0.803335
# [6400]	valid_0's custom_score: 0.80259
# [6600]	valid_0's custom_score: 0.804328
# [6800]	valid_0's custom_score: 0.80559
# Learning rate adjusted to 0.02657205000000001
# [7000]	valid_0's custom_score: 0.803111
# [7200]	valid_0's custom_score: 0.803377
# [7400]	valid_0's custom_score: 0.803377
# [7600]	valid_0's custom_score: 0.803044
# [7800]	valid_0's custom_score: 0.802833
# Learning rate adjusted to 0.02391484500000001
# [8000]	valid_0's custom_score: 0.803695
# [8200]	valid_0's custom_score: 0.803565
# [8400]	valid_0's custom_score: 0.803286
# [8600]	valid_0's custom_score: 0.805088
# [8800]	valid_0's custom_score: 0.805068
# Learning rate adjusted to 0.021523360500000012
# [9000]	valid_0's custom_score: 0.804592
# Early stopping, best iteration is:
# [6665]	valid_0's custom_score: 0.806008
# Evaluated only: custom_score
# best_valid_score: 0.8060084394478723
# gbm position: 9

# %%
re_gbm = gbms[1]

# %%
y_pred = re_gbm.predict(feats.iloc[n_original:, :-1])

# %%
df_submit["mRNA_remaining_pct"] = y_pred
df_submit.to_csv("siRNA_0715/submission_task3_try1.csv", index=False)
